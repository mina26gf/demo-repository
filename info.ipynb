# %% [markdown]
# <a href="https://colab.research.google.com/github/mina26gf/demo-repository/blob/main/info.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive

# %%
import pandas as pd

df = pd.read_table(
    '/content/drive/MyDrive/projekt1/iris/iris.data',
    sep=',',
    header=None,
    names=['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class']
)
